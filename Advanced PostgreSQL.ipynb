# %% [markdown]
# # Advanced PostgreSQL

# %% [markdown]
# <h1>Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#SQL-Data-Types" data-toc-modified-id="SQL-Data-Types-1">SQL Data Types</a></span><ul class="toc-item"><li><span><a href="#Data-types" data-toc-modified-id="Data-types-1.1">Data types</a></span></li><li><span><a href="#Changing-a-column's-data-type" data-toc-modified-id="Changing-a-column's-data-type-1.2">Changing a column's data type</a></span><ul class="toc-item"><li><span><a href="#Practice-Problem" data-toc-modified-id="Practice-Problem-1.2.1">Practice Problem</a></span></li></ul></li></ul></li><li><span><a href="#SQL-Date-Format" data-toc-modified-id="SQL-Date-Format-2">SQL Date Format</a></span><ul class="toc-item"><li><span><a href="#Why-dates-are-formatted-year-first" data-toc-modified-id="Why-dates-are-formatted-year-first-2.1">Why dates are formatted year-first</a></span></li><li><span><a href="#Rules-for-dates-and-times" data-toc-modified-id="Rules-for-dates-and-times-2.2">Rules for dates and times</a></span><ul class="toc-item"><li><span><a href="#Practice-Problem" data-toc-modified-id="Practice-Problem-2.2.1">Practice Problem</a></span></li></ul></li></ul></li><li><span><a href="#Data-Wrangling-with-SQL" data-toc-modified-id="Data-Wrangling-with-SQL-3">Data Wrangling with SQL</a></span><ul class="toc-item"><li><span><a href="#What-does-it-mean-to-&quot;wrangle&quot;-data?" data-toc-modified-id="What-does-it-mean-to-&quot;wrangle&quot;-data?-3.1">What does it mean to "wrangle" data?</a></span></li></ul></li><li><span><a href="#Using-SQL-String-Functions-to-Clean-Data" data-toc-modified-id="Using-SQL-String-Functions-to-Clean-Data-4">Using SQL String Functions to Clean Data</a></span><ul class="toc-item"><li><span><a href="#Cleaning-strings" data-toc-modified-id="Cleaning-strings-4.1">Cleaning strings</a></span></li><li><span><a href="#LEFT,-RIGHT,-and-LENGTH" data-toc-modified-id="LEFT,-RIGHT,-and-LENGTH-4.2">LEFT, RIGHT, and LENGTH</a></span></li><li><span><a href="#TRIM" data-toc-modified-id="TRIM-4.3">TRIM</a></span></li><li><span><a href="#POSITION-and-STRPOS" data-toc-modified-id="POSITION-and-STRPOS-4.4">POSITION and STRPOS</a></span></li><li><span><a href="#SUBSTR" data-toc-modified-id="SUBSTR-4.5">SUBSTR</a></span><ul class="toc-item"><li><span><a href="#Practice-Problem" data-toc-modified-id="Practice-Problem-4.5.1">Practice Problem</a></span></li></ul></li><li><span><a href="#CONCAT" data-toc-modified-id="CONCAT-4.6">CONCAT</a></span><ul class="toc-item"><li><span><a href="#Practice-Problem" data-toc-modified-id="Practice-Problem-4.6.1">Practice Problem</a></span></li></ul></li><li><span><a href="#Changing-case-with-UPPER-and-LOWER" data-toc-modified-id="Changing-case-with-UPPER-and-LOWER-4.7">Changing case with UPPER and LOWER</a></span><ul class="toc-item"><li><span><a href="#Practice-Problem" data-toc-modified-id="Practice-Problem-4.7.1">Practice Problem</a></span></li></ul></li><li><span><a href="#Turning-strings-into-dates" data-toc-modified-id="Turning-strings-into-dates-4.8">Turning strings into dates</a></span><ul class="toc-item"><li><span><a href="#Practice-Problem" data-toc-modified-id="Practice-Problem-4.8.1">Practice Problem</a></span></li></ul></li><li><span><a href="#Turning-dates-into-more-useful-dates" data-toc-modified-id="Turning-dates-into-more-useful-dates-4.9">Turning dates into more useful dates</a></span><ul class="toc-item"><li><span><a href="#Practice-Problem" data-toc-modified-id="Practice-Problem-4.9.1">Practice Problem</a></span></li><li><span><a href="#Practice-Problem" data-toc-modified-id="Practice-Problem-4.9.2">Practice Problem</a></span></li></ul></li><li><span><a href="#COALESCE" data-toc-modified-id="COALESCE-4.10">COALESCE</a></span></li></ul></li><li><span><a href="#Writing-Subqueries-in-SQL" data-toc-modified-id="Writing-Subqueries-in-SQL-5">Writing Subqueries in SQL</a></span><ul class="toc-item"><li><span><a href="#Subquery-basics" data-toc-modified-id="Subquery-basics-5.1">Subquery basics</a></span><ul class="toc-item"><li><span><a href="#Practice-Problem" data-toc-modified-id="Practice-Problem-5.1.1">Practice Problem</a></span></li></ul></li><li><span><a href="#Using-subqueries-to-aggregate-in-multiple-stages" data-toc-modified-id="Using-subqueries-to-aggregate-in-multiple-stages-5.2">Using subqueries to aggregate in multiple stages</a></span><ul class="toc-item"><li><span><a href="#Practice-Problem" data-toc-modified-id="Practice-Problem-5.2.1">Practice Problem</a></span></li></ul></li><li><span><a href="#Subqueries-in-conditional-logic" data-toc-modified-id="Subqueries-in-conditional-logic-5.3">Subqueries in conditional logic</a></span></li><li><span><a href="#Joining-subqueries" data-toc-modified-id="Joining-subqueries-5.4">Joining subqueries</a></span><ul class="toc-item"><li><span><a href="#Practice-Problem" data-toc-modified-id="Practice-Problem-5.4.1">Practice Problem</a></span></li></ul></li><li><span><a href="#Subqueries-and-UNIONs" data-toc-modified-id="Subqueries-and-UNIONs-5.5">Subqueries and UNIONs</a></span><ul class="toc-item"><li><span><a href="#Practice-Problem" data-toc-modified-id="Practice-Problem-5.5.1">Practice Problem</a></span></li><li><span><a href="#Practice-Problem" data-toc-modified-id="Practice-Problem-5.5.2">Practice Problem</a></span></li></ul></li></ul></li><li><span><a href="#SQL-Window-Functions" data-toc-modified-id="SQL-Window-Functions-6">SQL Window Functions</a></span><ul class="toc-item"><li><span><a href="#Intro-to-window-functions" data-toc-modified-id="Intro-to-window-functions-6.1">Intro to window functions</a></span></li><li><span><a href="#Basic-windowing-syntax" data-toc-modified-id="Basic-windowing-syntax-6.2">Basic windowing syntax</a></span><ul class="toc-item"><li><span><a href="#Practice-Problem" data-toc-modified-id="Practice-Problem-6.2.1">Practice Problem</a></span></li></ul></li><li><span><a href="#The-usual-suspects:-SUM,-COUNT,-and-AVG" data-toc-modified-id="The-usual-suspects:-SUM,-COUNT,-and-AVG-6.3">The usual suspects: SUM, COUNT, and AVG</a></span><ul class="toc-item"><li><span><a href="#Practice-Problem" data-toc-modified-id="Practice-Problem-6.3.1">Practice Problem</a></span></li></ul></li><li><span><a href="#ROW_NUMBER()" data-toc-modified-id="ROW_NUMBER()-6.4">ROW_NUMBER()</a></span></li><li><span><a href="#RANK()-and-DENSE_RANK()" data-toc-modified-id="RANK()-and-DENSE_RANK()-6.5">RANK() and DENSE_RANK()</a></span></li><li><span><a href="#NTILE" data-toc-modified-id="NTILE-6.6">NTILE</a></span></li><li><span><a href="#LAG-and-LEAD" data-toc-modified-id="LAG-and-LEAD-6.7">LAG and LEAD</a></span></li><li><span><a href="#Defining-a-window-alias" data-toc-modified-id="Defining-a-window-alias-6.8">Defining a window alias</a></span></li></ul></li><li><span><a href="#Performance-Tuning-SQL-Queries" data-toc-modified-id="Performance-Tuning-SQL-Queries-7">Performance Tuning SQL Queries</a></span><ul class="toc-item"><li><span><a href="#The-theory-behind-query-run-time" data-toc-modified-id="The-theory-behind-query-run-time-7.1">The theory behind query run time</a></span></li><li><span><a href="#Reducing-table-size" data-toc-modified-id="Reducing-table-size-7.2">Reducing table size</a></span></li><li><span><a href="#Making-JOINs-less-complicated" data-toc-modified-id="Making-JOINs-less-complicated-7.3">Making JOINs less complicated</a></span></li><li><span><a href="#Explain" data-toc-modified-id="Explain-7.4">Explain</a></span></li></ul></li><li><span><a href="#Pivoting-Data-in-SQL" data-toc-modified-id="Pivoting-Data-in-SQL-8">Pivoting Data in SQL</a></span><ul class="toc-item"><li><span><a href="#Pivoting-rows-to-columns" data-toc-modified-id="Pivoting-rows-to-columns-8.1">Pivoting rows to columns</a></span></li><li><span><a href="#Pivoting-columns-to-rows" data-toc-modified-id="Pivoting-columns-to-rows-8.2">Pivoting columns to rows</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## SQL Data Types

# %% [markdown]
# ### Data types

# %% [markdown]
# For a complete list of SQL data types [click here](https://www.w3schools.com/sql/sql_datatypes_general.asp)

# %% [markdown]
# ### Changing a column's data type

# %% [markdown]
# If data is not stored in its optimal format from the beginning, use `CAST` or `CONVERT` to change the data type in your query.
#
# For example, both
# ```sql
# CAST(column_name AS integer)
# ```
# and
# ```sql
# column_name::integer
# ```
# produce the same result and change the data type to a numeric one. Replace `integer` with any other data type - all values in a given column must fit with the new data types.

# %% [markdown]
# #### Practice Problem

# %% [markdown]
# > Convert the `funding_total_usd` and `founded_at_clean` columns
# > in the `tutorial.crunchbase_companies_clean_date` table to
# > strings (varchar format) using a different formatting function
# > for each one.

# %% [markdown]
# ```sql
# SELECT CAST(funding_total_usd AS varchar) AS funding_total_usd_str,
#        founded_at_clean::varchar AS founded_at_str
# FROM tutorial.crunchbase_companies_clean_date
# ```

# %% [markdown]
# ![img.png](attachment:img.png)

# %% [markdown]
# ## SQL Date Format

# %% [markdown]
# ### Why dates are formatted year-first

# %% [markdown]
# When dates are stored as strings in MM-DD-YYYY or DD-MM-YYYY format, the `ORDER BY`statement doesn't produce a chronological list.
#
# The YYYY-MM-DD date format will sort in chronological order whether it's stored as a date or as a string.

# %% [markdown]
# ### Rules for dates and times

# %% [markdown]
# When you perform arithmetic on dates (such as subtracting one date from another), the results are often stored as the `interval` data type — a series of integers that represent a period of time.
#
# The following query uses date subtraction to determine how long it took companies to be acquired (unacquired companies and those without dates entered were filtered out). Note that because the `companies.founded_at_clean` column is stored as a string, it must be cast as a timestamp before it can be subtracted from another timestamp.

# %% [markdown]
# ```sql
# SELECT companies.permalink,
#        companies.founded_at_clean,
#        acquisitions.acquired_at_cleaned,
#        acquisitions.acquired_at_cleaned -
#          companies.founded_at_clean::timestamp AS time_to_acquisition
#   FROM tutorial.crunchbase_companies_clean_date companies
#   JOIN tutorial.crunchbase_acquisitions_clean_date acquisitions
#     ON acquisitions.company_permalink = companies.permalink
#  WHERE founded_at_clean IS NOT NULL
# ```

# %% [markdown]
# ![img.png](attachment:img.png)

# %% [markdown]
# Note that the resulting `time_to_acquisition` column is an interval, not another date.

# %% [markdown]
# You can introduce intervals using the `INTERVAL` function as well:

# %% [markdown]
# ```sql
# SELECT companies.permalink,
#        companies.founded_at_clean,
#        companies.founded_at_clean::timestamp +
#          INTERVAL '1 week' AS plus_one_week
#   FROM tutorial.crunchbase_companies_clean_date companies
#  WHERE founded_at_clean IS NOT NULL
# ```

# %% [markdown]
# ![img.png](attachment:img.png)

# %% [markdown]
# **Note:** Adding or subtracting a `date` column and an `interval` column results in another `date` column as in the above query.

# %% [markdown]
# You can add the current time (at the time you run the query) into your code using the `NOW()` function:

# %% [markdown]
# ```sql
# SELECT companies.permalink,
#        companies.founded_at_clean,
#        NOW() - companies.founded_at_clean::timestamp AS founded_time_ago
#   FROM tutorial.crunchbase_companies_clean_date companies
#  WHERE founded_at_clean IS NOT NULL
# ```

# %% [markdown]
# ![img.png](attachment:img.png)

# %% [markdown]
# #### Practice Problem

# %% [markdown]
# > Write a query that counts the number of companies acquired
# > within 3 years, 5 years, and 10 years of being founded (in 3
# > separate columns). Include a column for total companies
# > acquired as well. Group by category and limit to only rows with
# > a founding date.

# %% [markdown]
# ```sql
# SELECT companies.category_code,
#   COUNT(CASE WHEN acquisitions.acquired_at_cleaned <= companies.founded_at_clean::timestamp + INTERVAL '3 years'
#     THEN 1 ELSE NULL END) AS acquired_within_3yrs,
#   COUNT(CASE WHEN acquisitions.acquired_at_cleaned <= companies.founded_at_clean::timestamp + INTERVAL '5 years'
#     THEN 1 ELSE NULL END) AS acquired_within_5yrs,
#   COUNT(CASE WHEN acquisitions.acquired_at_cleaned <= companies.founded_at_clean::timestamp + INTERVAL '10 years'
#     THEN 1 ELSE NULL END) AS acquired_within_10yrs,
#   COUNT(1) AS total
# FROM tutorial.crunchbase_companies_clean_date companies
# JOIN tutorial.crunchbase_acquisitions_clean_date acquisitions
# ON acquisitions.company_permalink = companies.permalink
# WHERE founded_at_clean IS NOT NULL
# GROUP BY 1
# ORDER BY 5 DESC
# ```

# %% [markdown]
# ![img-3.png](attachment:img-3.png)

# %% [markdown]
# ## Data Wrangling with SQL

# %% [markdown]
# ### What does it mean to "wrangle" data?

# %% [markdown]
# Data wrangling (or munging) is the process of programmatically transforming data into a format that makes it easier to work with.
#
# The necessity for data wrangling is often a biproduct of poorly collected or presented data. Data that is entered manually by humans is typically fraught with errors; data collected from websites is often optimized to be displayed on websites, not to be sorted and aggregated.

# %% [markdown]
# This lesson features data on San Francisco Crime Incidents for the 3-month period beginning November 1, 2013 and ending January 31, 2014. There is one row for each incident reported. Some field definitions: `location` is the GPS location of the incident, listed in **decimal degrees**, latitude first, longitude second. The two coordinates are also broken out into the `lat` and `lon` fields, respectively.

# %%
import pandas as pd
data = pd.read_csv('/users/bm/downloads/csv_files/sf_crime_incidents_2014.csv')
data.head()
# Out:
#    incidnt_num        category                               descript  \
# 0  140099416.0   VEHICLE THEFT           STOLEN AND RECOVERED VEHICLE
# 1  140092426.0         ASSAULT                                BATTERY
# 2  140092410.0  SUSPICIOUS OCC                  SUSPICIOUS OCCURRENCE
# 3  140092341.0  OTHER OFFENSES  DRIVERS LICENSE, SUSPENDED OR REVOKED
# 4  140092573.0   DRUG/NARCOTIC  POSSESSION OF NARCOTICS PARAPHERNALIA
#
#   day_of_week                          date   time pd_district  \
# 0      Friday  01/31/2014 08:00:00 AM +0000  17:00   INGLESIDE
# 1      Friday  01/31/2014 08:00:00 AM +0000  17:45     TARAVAL
# 2      Friday  01/31/2014 08:00:00 AM +0000  15:30        PARK
# 3      Friday  01/31/2014 08:00:00 AM +0000  17:50     CENTRAL
# 4      Friday  01/31/2014 08:00:00 AM +0000  19:20    SOUTHERN
#
#        resolution                   address         lon        lat  \
# 0            NONE    0 Block of GARRISON AV -122.413624  37.709726
# ...

# %% [markdown]
# ## Using SQL String Functions to Clean Data

# %% [markdown]
# ### Cleaning strings

# %% [markdown]
# `LEFT`, `RIGHT`, and `TRIM` are all used to select only certain elements of strings, but using them to select elements of a number or date will treat them as strings for the purpose of the function.

# %% [markdown]
# ### LEFT, RIGHT, and LENGTH

# %% [markdown]
# `LEFT` is used to pull a certain number of characters from the left side of a string and present them as a separate string. `RIGHT` does the same thing from the right side.

# %% [markdown]
# **syntax:**
# ```sql
# LEFT(string, number of characters)
# ```
# ```sql
# RIGHT(string, number of characters)
# ```

# %% [markdown]
# ```sql
# SELECT incidnt_num,
#        date,
#        LEFT(date, 10) AS cleaned_date
#        RIGHT(date, 17) AS cleaned_time
#   FROM tutorial.sf_crime_incidents_2014_01
# ```

# %% [markdown]
# ![img.png](attachment:img.png)

# %% [markdown]
# If the number of characters in the date field is not consistent throughout, and since we know that the first 10 characters will be the date, followed by a space (total 11 characters), we could represent the `RIGHT` function as follows:

# %% [markdown]
# ```sql
# SELECT incidnt_num,
#        date,
#        LEFT(date, 10) AS cleaned_date,
#        RIGHT(date, LENGTH(date) - 11) AS cleaned_time
#   FROM tutorial.sf_crime_incidents_2014_01
# ```

# %% [markdown]
# ### TRIM

# %% [markdown]
# The `TRIM` function is used to remove characters from the beginning and end of a string.

# %% [markdown]
# ```sql
# SELECT location,
#        TRIM(both '()' FROM location)
#   FROM tutorial.sf_crime_incidents_2014_01
# ```

# %% [markdown]
# ![img.png](attachment:img.png)

# %% [markdown]
# * First, specify whether to remove characters from the beginning ('leading'), the end ('trailing'), or both ('both') ends
# * Next, specify all characters to be trimmed in single quotes
# * Finally, specify the text to be trimmed using `FROM`

# %% [markdown]
#    ### POSITION and STRPOS

# %% [markdown]
# **Example:**
#
# The following query will return the position of the character 'A'(case-sensitive) where it first appears in the `descript` field:

# %% [markdown]
# ```sql
# SELECT incidnt_num,
#        descript,
#        POSITION('A' IN descript) AS a_position
#   FROM tutorial.sf_crime_incidents_2014_01
# ```

# %% [markdown]
# ![img.png](attachment:img.png)

# %% [markdown]
# The `STRPOS` function gives the same result:

# %% [markdown]
# ```sql
# SELECT incidnt_num,
#        descript,
#        STRPOS(descript, 'A') AS a_position
#   FROM tutorial.sf_crime_incidents_2014_01
# ```

# %% [markdown]
# **Note:** Both the `POSITION` and `STRPOS` functions are case-sensitive

# %% [markdown]
# ### SUBSTR

# %% [markdown]
# To create a substring starting in the middle of a string, use `SUBSTR`

# %% [markdown]
# **syntax:**

# %% [markdown]
# ```sql
# SELECT incidnt_num,
#        date,
#        SUBSTR(date, 4, 2) AS day
#   FROM tutorial.sf_crime_incidents_2014_01
# ```

# %% [markdown]
# ![img.png](attachment:img.png)

# %% [markdown]
# #### Practice Problem

# %% [markdown]
# > Write a query that separates the 'location' field into separate
# > fields for latitude and longitude. Compare your results against
# > the actual 'lat' and 'lon' fields in the table.

# %% [markdown]
# ```sql
# SELECT location,
#        lat,
#        lon,
#        TRIM(leading '(' FROM LEFT(location, POSITION(',' IN location)-1)) AS latitude,
#        TRIM(trailing ')' FROM RIGHT(location, LENGTH(location)-POSITION(',' IN location))) AS longitude
#   FROM tutorial.sf_crime_incidents_2014_01
# ```

# %% [markdown]
# ![img.png](attachment:img.png)

# %% [markdown]
# ### CONCAT

# %% [markdown]
# Combine strings from several columns together (and with hard-coded values) using `CONCAT`. Simply order the values you want to concatenate and separate them with commas. If you want to hard-code values, enclose them in single quotes.

# %% [markdown]
# ```sql
# SELECT incidnt_num,
#        day_of_week,
#        LEFT(date, 10) AS cleaned_date,
#        CONCAT(day_of_week, ', ', LEFT(date, 10)) AS day_and_date
#   FROM tutorial.sf_crime_incidents_2014_01
# ```

# %% [markdown]
# ![img.png](attachment:img.png)

# %% [markdown]
# **Alternate method** using two pipe characters `(||)`

# %% [markdown]
# ```sql
# SELECT incidnt_num,
#        day_of_week,
#        LEFT(date, 10) AS cleaned_date,
#        day_of_week || ', ' || LEFT(date, 10) AS day_and_date
#   FROM tutorial.sf_crime_incidents_2014_01
# ```

# %% [markdown]
# #### Practice Problem

# %% [markdown]
# > Concatenate the `lat` and `lon` fields to form a field that is
# > equivalent to the `location` field. (Note that the answer will
# > have a different decimal precision.)

# %% [markdown]
# ```sql
# SELECT lat,
#        lon,
#        CONCAT('(', lat, ', ', lon, ')') AS loc
#   FROM tutorial.sf_crime_incidents_2014_01
# ```

# %% [markdown]
# ![img.png](attachment:img.png)

# %% [markdown]
# > Create the same concatenated `location` field, but using the
# > `||` syntax instead of `CONCAT`

# %% [markdown]
# ```sql
# SELECT lat,
#        lon,
#        '(' || lat || ', ' || lon || ')' AS loc
# FROM tutorial.sf_crime_incidents_2014_01
# ```

# %% [markdown]
# > Write a query that creates a date column formatted YYYY-MM-DD

# %% [markdown]
# ```sql
# SELECT incidnt_num,
#        day_of_week,
#        date,
#        SUBSTR(date, 7, 4) || '-' || LEFT(date, 2) || '-' || SUBSTR(date, 4, 2) AS new_date
# FROM tutorial.sf_crime_incidents_2014_01
# ```

# %% [markdown]
# ![img.png](attachment:img.png)

# %% [markdown]
# ### Changing case with UPPER and LOWER

# %% [markdown]
# **Example:**

# %% [markdown]
# ```sql
# SELECT incidnt_num,
#        address,
#        UPPER(address) AS address_upper,
#        LOWER(address) AS address_lower
#   FROM tutorial.sf_crime_incidents_2014_01
# ```

# %% [markdown]
# ![img.png](attachment:img.png)

# %% [markdown]
# #### Practice Problem

# %% [markdown]
# > Write a query that returns the `category` field, but with the
# > first letter capitalized and the rest of the letters in lower-
# > case.

# %% [markdown]
# ```sql
# SELECT incidnt_num,
#        category,
#        UPPER(LEFT(category, 1)) || LOWER(RIGHT(category, LENGTH(category)-1)) AS category_cleaned
#   FROM tutorial.sf_crime_incidents_2014_01
# ```

# %% [markdown]
# ![img.png](attachment:img.png)

# %% [markdown]
# The [Postgres literature](http://www.postgresql.org/docs/9.1/static/functions-string.html) contains a number of variations of these functions, as well as several other string functions not covered here.

# %% [markdown]
# ### Turning strings into dates

# %% [markdown]
# Formatting a date field appropriately involves some text manipulation, followed by a `CAST`.

# %% [markdown]
# **Example:**

# %% [markdown]
# Write a query that creates a date column formatted YYYY-MM-DD. Cast the result in the `date` format.

# %% [markdown]
# ```sql
# SELECT incidnt_num,
#        date,
#        (SUBSTR(date, 7, 4) || '-' || LEFT(date, 2) || '-' || SUBSTR(date, 4, 2))::date AS cleaned_date
#   FROM tutorial.sf_crime_incidents_2014_01
# ```

# %% [markdown]
# ![img.png](attachment:img.png)

# %% [markdown]
# #### Practice Problem

# %% [markdown]
# Write a query that creates an accurate timestamp using the `date` and `time` columns in `tutorial.sf_crime_incidents_2014_01`. Include a field that is exactly 1 week later as well.

# %% [markdown]
# ```sql
# SELECT incidnt_num,
#        (SUBSTR(date, 7, 4) || '-' || LEFT(date, 2) ||
#         '-' || SUBSTR(date, 4, 2) || ' ' || time || ':00')::timestamp AS timestamp,
#        (SUBSTR(date, 7, 4) || '-' || LEFT(date, 2) ||
#         '-' || SUBSTR(date, 4, 2) || ' ' || time || ':00')::timestamp
#         + INTERVAL '1 week' AS timestamp_plus_interval
#   FROM tutorial.sf_crime_incidents_2014_01
# ```

# %% [markdown]
# ![img.png](attachment:img.png)

# %% [markdown]
# ### Turning dates into more useful dates

# %% [markdown]
# Once the date field has been well-formatted, we can manipulate it in other ways. A different version of the crime incidents dataset that already has a nicely-formatted date field will be used in the following examples.

# %%
new_data = pd.read_csv('/users/bm/downloads/csv_files/sf_crime_incidents_cleandate.csv')
new_data.head()
# Out:
#    incidnt_num        category                               descript  \
# 0  140099416.0   VEHICLE THEFT           STOLEN AND RECOVERED VEHICLE
# 1  140092426.0         ASSAULT                                BATTERY
# 2  140092410.0  SUSPICIOUS OCC                  SUSPICIOUS OCCURRENCE
# 3  140092341.0  OTHER OFFENSES  DRIVERS LICENSE, SUSPENDED OR REVOKED
# 4  140092573.0   DRUG/NARCOTIC  POSSESSION OF NARCOTICS PARAPHERNALIA
#
#   day_of_week                          date   time pd_district  \
# 0      Friday  01/31/2014 08:00:00 AM +0000  17:00   INGLESIDE
# 1      Friday  01/31/2014 08:00:00 AM +0000  17:45     TARAVAL
# 2      Friday  01/31/2014 08:00:00 AM +0000  15:30        PARK
# 3      Friday  01/31/2014 08:00:00 AM +0000  17:50     CENTRAL
# 4      Friday  01/31/2014 08:00:00 AM +0000  19:20    SOUTHERN
#
#        resolution                   address         lon        lat  \
# 0            NONE    0 Block of GARRISON AV -122.413624  37.709726
# ...

# %% [markdown]
# Use `EXTRACT` to deconstruct a date field and pull the pieces apart one-by-one:

# %% [markdown]
# ```sql
# SELECT cleaned_date,
#        EXTRACT('year'     FROM cleaned_date) AS year,
#        EXTRACT('month'    FROM cleaned_date) AS month,
#        EXTRACT('day'      FROM cleaned_date) AS day,
#        EXTRACT('hour'     FROM cleaned_date) AS hour,
#        EXTRACT('minute'   FROM cleaned_date) AS minute,
#        EXTRACT('second'   FROM cleaned_date) AS second,
#        EXTRACT('decade'   FROM cleaned_date) AS decade,
#        EXTRACT('dow'      FROM cleaned_date) AS day_of_week
#   FROM tutorial.sf_crime_incidents_cleandate
# ```

# %% [markdown]
# ![img.png](attachment:img.png)

# %% [markdown]
# The `DATE_TRUNC` function rounds a date to whatever precision you specify. The value displayed is the first value in that period. So when you `DATE_TRUNC` by year, any value in that year will be listed as January 1st of that year:

# %% [markdown]
# ```sql
# SELECT cleaned_date,
#        DATE_TRUNC('year'   , cleaned_date) AS year,
#        DATE_TRUNC('month'  , cleaned_date) AS month,
#        DATE_TRUNC('week'   , cleaned_date) AS week,
#        DATE_TRUNC('day'    , cleaned_date) AS day,
#        DATE_TRUNC('hour'   , cleaned_date) AS hour,
#        DATE_TRUNC('minute' , cleaned_date) AS minute,
#        DATE_TRUNC('second' , cleaned_date) AS second,
#        DATE_TRUNC('decade' , cleaned_date) AS decade
#   FROM tutorial.sf_crime_incidents_cleandate
# ```

# %% [markdown]
# ![img.png](attachment:img.png)

# %% [markdown]
# #### Practice Problem

# %% [markdown]
# Write a query that counts the number of incidents reported by week. Cast the week as a date to get rid of the hours/minutes/seconds

# %% [markdown]
# ```sql
# SELECT DATE_TRUNC('week', cleaned_date)::date AS week_beginning,
#        COUNT(*) AS incidents
#   FROM tutorial.sf_crime_incidents_cleandate
#  GROUP BY 1
#  ORDER BY 1 DESC
# ```

# %% [markdown]
# ![img.png](attachment:img.png)

# %% [markdown]
# To instruct your query to pull the local date and time at the time the query is run:

# %% [markdown]
# ```sql
# SELECT CURRENT_DATE AS date,
#        CURRENT_TIME AS time,
#        CURRENT_TIMESTAMP AS timestamp,
#        LOCALTIME AS localtime,
#        LOCALTIMESTAMP AS localtimestamp,
#        NOW() AS now
# ```

# %% [markdown]
# ![jmg.png](attachment:jmg.png)

# %% [markdown]
# <i>**Note:** Results will vary depending on the timezone setting of the database</i>

# %% [markdown]
# To make a time appear in a different time zone use `AT TIME ZONE`. For a complete list of timezones, [look here](http://www.postgresql.org/docs/7.2/static/timezones.html).

# %% [markdown]
# ```sql
# SELECT CURRENT_TIME AS time,
#        CURRENT_TIME AT TIME ZONE 'PST' AS time_pst
# ```

# %% [markdown]
# ![img.png](attachment:img.png)

# %% [markdown]
# #### Practice Problem

# %% [markdown]
# Write a query that shows exactly how long ago each indicent was reported. Assume that the dataset is in Pacific Standard Time (UTC - 8).

# %% [markdown]
# ```sql
# SELECT incidnt_num,
#        cleaned_date,
#        NOW() AT TIME ZONE 'PST' AS now,
#        NOW() AT TIME ZONE 'PST' - cleaned_date AS time_ago
#   FROM tutorial.sf_crime_incidents_cleandate
# ```

# %% [markdown]
# ![img.png](attachment:img.png)

# %% [markdown]
# ### COALESCE

# %% [markdown]
# Use `COALESCE` to replace null values in a dataset with actual values.

# %% [markdown]
# ```sql
# SELECT incidnt_num,
#        descript,
#        COALESCE(descript, 'No Description')
#   FROM tutorial.sf_crime_incidents_cleandate
#  ORDER BY descript DESC
# ```

# %% [markdown]
# ![img.png](attachment:img.png)

# %% [markdown]
# ## Writing Subqueries in SQL

# %% [markdown]
# ### Subquery basics

# %% [markdown]
# Subqueries (also known as inner queries or nested queries) are a tool for performing operations in multiple steps.

# %% [markdown]
# **Example of a basic subquery:**

# %% [markdown]
# ```sql
# SELECT sub.*
#   FROM (
#         SELECT *
#           FROM tutorial.sf_crime_incidents_2014_01
#          WHERE day_of_week = 'Friday'
#        ) sub
#  WHERE sub.resolution = 'NONE'
# ```

# %% [markdown]
# * First, the database runs the "inner query"—the part between the parentheses
# * Once the inner query runs, the outer query will run using the results from the inner query as its underlying table
# * Subqueries are required to have names, which are added after parentheses the same way you would add an alias to a normal table. In this case, we've used the name "sub."

# %% [markdown]
# #### Practice Problem

# %% [markdown]
# Write a query that selects all Warrant Arrests from the `tutorial.sf_crime_incidents_2014_01` dataset, then wrap it in an outer query that only displays unresolved incidents.

# %% [markdown]
# ```sql
# SELECT sub.*
#       FROM (
#             SELECT *
#               FROM tutorial.sf_crime_incidents_2014_01
#              WHERE descript = 'WARRANT ARREST'
#            ) sub
#      WHERE sub.resolution = 'NONE'
# ```

# %% [markdown]
# **Note:** The above problems don't really require subqueries - they could also be solved by adding multiple conditions to the `WHERE` clause.

# %% [markdown]
# ### Using subqueries to aggregate in multiple stages

# %% [markdown]
# What if you wanted to know how many incidents happen, on average, on a Friday in December? In January? There are two steps to this process: counting the number of incidents each day (inner query), then determining the monthly average (outer query):

# %% [markdown]
# ```sql
# -- inner query
# SELECT day_of_week,
#        date,
#        COUNT(incidnt_num) AS incidents
#   FROM tutorial.sf_crime_incidents_2014_01
# GROUP BY 1,2
# ```

# %% [markdown]
# ```sql
# -- result of inner query
# ```
# ![img.png](attachment:img.png)

# %% [markdown]
# ```sql
# -- add outer query
# SELECT LEFT(sub.date, 2) AS cleaned_month,
#        sub.day_of_week,
#        AVG(sub.incidents) AS average_incidents
#   FROM (
#         SELECT day_of_week,
#                date,
#                COUNT(incidnt_num) AS incidents
#           FROM tutorial.sf_crime_incidents_2014_01
#          GROUP BY 1,2
#        ) sub
#  GROUP BY 1,2
#  ORDER BY 1,2
# ```

# %% [markdown]
# ```sql
# -- final result
# ```
# ![img.png](attachment:img.png)

# %% [markdown]
# #### Practice Problem

# %% [markdown]
# Write a query that displays the average number of monthly incidents for each category. Use `tutorial.sf_crime_incidents_cleandate`.

# %% [markdown]
# ```sql
# SELECT sub.category,
#        AVG(sub.incidents) AS avg_incidents_per_month
#   FROM (
#         SELECT EXTRACT('month' FROM cleaned_date) AS month,
#                category,
#                COUNT(1) AS incidents
#           FROM tutorial.sf_crime_incidents_cleandate
#          GROUP BY 1,2
#        ) sub
#  GROUP BY 1
# ```

# %% [markdown]
# ```sql
# -- result of inner query
# ```
# ![img.png](attachment:img.png)

# %% [markdown]
# ```sql
# -- final result
# ```
# ![img.png](attachment:img.png)

# %% [markdown]
# ### Subqueries in conditional logic

# %% [markdown]
# Subqueries can be used in conditional logic (in conjunction with `WHERE`, `JOIN`/`ON`, or `CASE`).

# %% [markdown]
# The following query returns all of the entries from the earliest date in the dataset:

# %% [markdown]
# ```sql
# SELECT *
#   FROM tutorial.sf_crime_incidents_2014_01
#  WHERE Date = (SELECT MIN(date)
#                  FROM tutorial.sf_crime_incidents_2014_01
#               )
# ```

# %% [markdown]
# ```sql
# -- note: not all columns are shown
# ```
# ![img.png](attachment:img.png)

# %% [markdown]
# The above query works because the result of the subquery is only one cell. Most conditional logic will work with subqueries containing one-cell results. However, `IN` is the only type of conditional logic that will work when the inner query contains multiple results:

# %% [markdown]
# ```sql
# SELECT *
#   FROM tutorial.sf_crime_incidents_2014_01
#  WHERE Date IN (SELECT date
#                  FROM tutorial.sf_crime_incidents_2014_01
#                 ORDER BY date
#                 LIMIT 5
#               )
# ```

# %% [markdown]
# Do not include an alias when you write a subquery in a conditional statement. This is because the subquery is treated as an individual value (or set of values in the `IN` case) rather than as a table.

# %% [markdown]
# ### Joining subqueries

# %% [markdown]
# When you join, the requirements for your subquery output aren't as stringent as when you use the `WHERE` clause.
#
# For example, your inner query can output multiple results. The following query ranks all of the results according to how many incidents were reported in a given day. It does this by aggregating the total number of incidents each day in the inner query, then using those values to sort the outer query:

# %% [markdown]
# ```sql
# -- inner query
#  SELECT date,
#           COUNT(incidnt_num) AS incidents
#            FROM tutorial.sf_crime_incidents_2014_01
#           GROUP BY 1
# ```

# %% [markdown]
# ```sql
# -- result of inner query
# ```
# ![img.png](attachment:img.png)

# %% [markdown]
# ```sql
# SELECT incidents.*,
#        sub.incidents AS incidents_that_day
#   FROM tutorial.sf_crime_incidents_2014_01 incidents
#   JOIN ( SELECT date,
#           COUNT(incidnt_num) AS incidents
#            FROM tutorial.sf_crime_incidents_2014_01
#           GROUP BY 1
#        ) sub
#     ON incidents.date = sub.date
#  ORDER BY sub.incidents DESC, time
#  ```

# %% [markdown]
# ```sql
# -- final result
# ```
# ![img.png](attachment:img.png)

# %% [markdown]
# #### Practice Problem

# %% [markdown]
# Write a query that displays all rows from the three categories with the fewest incidents reported.

# %% [markdown]
# ```sql
# -- inner query
# SELECT category,
#                COUNT(*) AS count
#           FROM tutorial.sf_crime_incidents_2014_01
#          GROUP BY 1
#          ORDER BY 2
#          LIMIT 3
# ```

# %% [markdown]
# ```sql
# -- result of inner query
# ```
# ![img.png](attachment:img.png)

# %% [markdown]
# ```sql
# SELECT incidents.*,
#        sub.count AS total_incidents_in_category
#   FROM tutorial.sf_crime_incidents_2014_01 incidents
#   JOIN (
#         SELECT category,
#                COUNT(*) AS count
#           FROM tutorial.sf_crime_incidents_2014_01
#          GROUP BY 1
#          ORDER BY 2
#          LIMIT 3
#        ) sub
#     ON sub.category = incidents.category
# ```

# %% [markdown]
# ```sql
# -- final result (not all columns shown)
# ```
# ![img.png](attachment:img.png)

# %% [markdown]
# ### Subqueries and UNIONs

# %% [markdown]
# It's not uncommon for a dataset to come split into several parts, especially if the data passed through Excel at any point (Excel can only handle ~1M rows per spreadsheet).

# %% [markdown]
# ```sql
# SELECT *
#   FROM tutorial.crunchbase_investments_part1
#
#  UNION ALL
#
#  SELECT *
#    FROM tutorial.crunchbase_investments_part2
# ```

# %% [markdown]
# The two tables used above can be thought of as different parts of the same dataset—what you'd almost certainly like to do is perform operations on the entire combined dataset rather than on the individual parts. You can do this by using a subquery:

# %% [markdown]
# ```sql
# SELECT COUNT(*) AS total_rows
#   FROM (
#         SELECT *
#           FROM tutorial.crunchbase_investments_part1
#
#          UNION ALL
#
#         SELECT *
#           FROM tutorial.crunchbase_investments_part2
#        ) sub
# ```

# %% [markdown]
# #### Practice Problem

# %% [markdown]
# Write a query that ranks investors from the combined dataset above by the total number of investments they have made.

# %% [markdown]
# ```sql
# SELECT investor_name,
#        COUNT(*) AS investments
#   FROM (
#         SELECT *
#           FROM tutorial.crunchbase_investments_part1
#
#          UNION ALL
#
#          SELECT *
#            FROM tutorial.crunchbase_investments_part2
#        ) sub
#  GROUP BY 1
#  ORDER BY 2 DESC
# ```

# %% [markdown]
# ![img.png](attachment:img.png)

# %% [markdown]
# #### Practice Problem

# %% [markdown]
# Write a query that does the same thing as in the previous problem, except only for companies that are still operating. Hint: operating status is in `tutorial.crunchbase_companies`.

# %% [markdown]
# ```sql
# SELECT investments.investor_name,
#        COUNT(investments.*) AS investments
#   FROM tutorial.crunchbase_companies companies
#   JOIN (
#         SELECT *
#           FROM tutorial.crunchbase_investments_part1
#
#          UNION ALL
#
#          SELECT *
#            FROM tutorial.crunchbase_investments_part2
#        ) investments
#     ON investments.company_permalink = companies.permalink
#  WHERE companies.status = 'operating'
#  GROUP BY 1
#  ORDER BY 2 DESC
# ```

# %% [markdown]
# ![img.png](attachment:img.png)

# %% [markdown]
# ## SQL Window Functions

# %% [markdown]
# This lesson uses data from Washington DC's **Capital Bikeshare Program**, which publishes detailed trip-level historical data **on their website**. The data was downloaded in February, 2014, but is limited to data collected during the first quarter of 2012.
#
# Each row represents one ride. Most fields are self-explanatory, except rider_type: "Registered" indicates a monthly membership to the rideshare program, "Casual" incidates that the rider bought a 3-day pass. The start_time and end_time fields were cleaned up from their original forms to suit SQL date formatting—they are stored in this table as timestamps.

# %%
import pandas as pd
bikeshare_data = pd.read_csv('/users/bm/downloads/csv_files/tutorial.dc_bikeshare_q1_2012.csv')
bikeshare_data.head()
# Out:
#         duration  duration_seconds           start_time  \
# 0   0h 7m 55sec.             475.0  2012-01-01 00:04:00
# 1  0h 19m 22sec.            1162.0  2012-01-01 00:10:00
# 2   0h 19m 5sec.            1145.0  2012-01-01 00:10:00
# 3    0h 8m 5sec.             485.0  2012-01-01 00:15:00
# 4   0h 7m 51sec.             471.0  2012-01-01 00:15:00
#
#                     start_station  start_terminal             end_time  \
# 0    7th & R St NW / Shaw Library         31245.0  2012-01-01 00:11:00
# 1  Georgia & New Hampshire Ave NW         31400.0  2012-01-01 00:29:00
# 2  Georgia & New Hampshire Ave NW         31400.0  2012-01-01 00:29:00
# 3                  14th & V St NW         31101.0  2012-01-01 00:23:00
# 4             11th & Kenyon St NW         31102.0  2012-01-01 00:23:00
#
#                end_station  end_terminal bike_number  rider_type  id
# 0            7th & T St NW       31109.0      W01412  Registered   1
# ...

# %% [markdown]
# ### Intro to window functions

# %% [markdown]
# A window function performs a calculation across a set of table rows that are somehow related to the current row. This is comparable to the type of calculation that can be done with an aggregate function.
#
# But unlike regular aggregate functions, use of a window function does not cause rows to become grouped into a single output row — the rows retain their separate identities. Behind the scenes, the window function is able to access more than just the current row of the query result.

# %% [markdown]
# The following query creates an aggregation (`running_total`) without using `GROUP BY`.

# %% [markdown]
# ```sql
# SELECT duration_seconds,
#        SUM(duration_seconds) OVER (ORDER BY start_time) AS running_total
#   FROM tutorial.dc_bikeshare_q1_2012
# ```

# %% [markdown]
# ![img.png](attachment:img.png)

# %% [markdown]
# ### Basic windowing syntax

# %% [markdown]
# The first part of the above aggregation, `SUM(duration_seconds)`, is like any other aggregation. Adding `OVER` designates it as a window function. You could read the above aggregation as "take the sum of `duration_seconds` over the entire result set, in order by `start_time`."
#
# If you'd like to narrow the window from the entire dataset to individual groups within the dataset, you can use `PARTITION BY` to do so:

# %% [markdown]
# ```sql
# SELECT start_terminal,
#        duration_seconds,
#        SUM(duration_seconds) OVER
#          (PARTITION BY start_terminal ORDER BY start_time)
#          AS running_total
#   FROM tutorial.dc_bikeshare_q1_2012
#  WHERE start_time < '2012-01-08'
# ```

# %% [markdown]
# ![img.png](attachment:img.png)

# %% [markdown]
# The above query groups and orders the query by `start_terminal`. Within each value of `start_terminal`, it is ordered by `start_time`, and the running total sums across the current row and all previous rows of `duration_seconds`. Scroll down until the `start_terminal` value changes and you will notice that `running_total` starts over.
#
# The `ORDER` and `PARTITION` define what is referred to as the "window"—the ordered subset of data over which calculations are made.
#
# **Note:** You can't use window functions and standard aggregations in the same query. More specifically, you can't include window functions in a `GROUP BY` clause.

# %% [markdown]
# #### Practice Problem

# %% [markdown]
# Write a query modification of the above example query that shows the duration of each ride as a percentage of the total time accrued by riders from each start_terminal

# %% [markdown]
# ```sql
# SELECT start_terminal,
#        duration_seconds,
#        SUM(duration_seconds) OVER (PARTITION BY start_terminal) AS start_terminal_sum,
#        (100*duration_seconds/SUM(duration_seconds) OVER (PARTITION BY start_terminal)) AS pct_of_total_time
#   FROM tutorial.dc_bikeshare_q1_2012
#  WHERE start_time < '2012-01-08'
#  ORDER BY 1, 4 DESC
# ```

# %% [markdown]
# ![img.png](attachment:img.png)

# %% [markdown]
# ### The usual suspects: SUM, COUNT, and AVG

# %% [markdown]
# When using window functions, you can apply the same aggregates that you would under normal circumstances— `SUM`, `COUNT`, and `AVG`.

# %% [markdown]
# ```sql
# SELECT start_terminal,
#        duration_seconds,
#        SUM(duration_seconds) OVER
#          (PARTITION BY start_terminal) AS running_total,
#        COUNT(duration_seconds) OVER
#          (PARTITION BY start_terminal) AS running_count,
#        AVG(duration_seconds) OVER
#          (PARTITION BY start_terminal) AS running_avg
#   FROM tutorial.dc_bikeshare_q1_2012
#  WHERE start_time < '2012-01-08'
# ```

# %% [markdown]
# ![img.png](attachment:img.png)

# %% [markdown]
# Alternatively, the same functions with `ORDER BY`:

# %% [markdown]
# ```sql
# SELECT start_terminal,
#        duration_seconds,
#        SUM(duration_seconds) OVER
#          (PARTITION BY start_terminal ORDER BY start_time)
#          AS running_total,
#        COUNT(duration_seconds) OVER
#          (PARTITION BY start_terminal ORDER BY start_time)
#          AS running_count,
#        AVG(duration_seconds) OVER
#          (PARTITION BY start_terminal ORDER BY start_time)
#          AS running_avg
#   FROM tutorial.dc_bikeshare_q1_2012
#  WHERE start_time < '2012-01-08'
# ```

# %% [markdown]
# ![img.png](attachment:img.png)

# %% [markdown]
# #### Practice Problem

# %% [markdown]
# Write a query that shows a running total of the duration of bike rides, but grouped by end_terminal, and with ride duration sorted in descending order.

# %% [markdown]
# ```sql
# SELECT end_terminal,
#        duration_seconds,
#        SUM(duration_seconds) OVER
#          (PARTITION BY end_terminal ORDER BY duration_seconds DESC)
#          AS running_total
#   FROM tutorial.dc_bikeshare_q1_2012
#  WHERE start_time < '2012-01-08'
# ```

# %% [markdown]
# ![img.png](attachment:img.png)

# %% [markdown]
# ### ROW_NUMBER()

# %% [markdown]
# `ROW_NUMBER()` displays the number of a given row. It starts at 1 and numbers the rows according to the `ORDER BY` part of the window statement.

# %% [markdown]
# ```sql
# SELECT start_terminal,
#        start_time,
#        duration_seconds,
#        ROW_NUMBER() OVER (ORDER BY start_time)
#                     AS row_number
#   FROM tutorial.dc_bikeshare_q1_2012
#  WHERE start_time < '2012-01-08'
# ```

# %% [markdown]
# ![img.png](attachment:img.png)

# %% [markdown]
# Using the `PARTITION BY` clause will allow you to begin counting 1 again in each partition.

# %% [markdown]
# ```sql
# SELECT start_terminal,
#        start_time,
#        duration_seconds,
#        ROW_NUMBER() OVER (PARTITION BY start_terminal
#                           ORDER BY start_time)
#                     AS row_number
#   FROM tutorial.dc_bikeshare_q1_2012
#  WHERE start_time < '2012-01-08'
#  ```

# %% [markdown]
# ![img.png](attachment:img.png)

# %% [markdown]
# ### RANK() and DENSE_RANK()

# %% [markdown]
# If you order by `start_time`, for example, it might be the case that some terminals have rides with two identical start times. In this case, they are given the same rank.
#
# In the following query, you notice the 4th and 5th observations for start_terminal 31000—they are both given a rank of 4, and the following result receives a rank of 6:

# %% [markdown]
# ```sql
# SELECT start_terminal,
#        duration_seconds,
#        RANK() OVER (PARTITION BY start_terminal
#                     ORDER BY start_time)
#               AS rank
#   FROM tutorial.dc_bikeshare_q1_2012
#  WHERE start_time < '2012-01-08'
# ```

# %% [markdown]
# ![img.png](attachment:img.png)

# %% [markdown]
# * `RANK()` gives the identical rows a rank of 4, then skips rank 5, so the next result is 6
# * `DENSE_RANK()` would still give the identical rows a rank of 4, but the following row would be 5—no ranks would be skipped.

# %% [markdown]
# **Practice Problem**
#
# Write a query that shows the 5 longest rides from each starting terminal, ordered by terminal, and longest to shortest rides within each terminal. Limit to rides that occurred before Jan. 8, 2012.

# %% [markdown]
# ```sql
# SELECT *
#   FROM (
#         SELECT start_terminal,
#                start_time,
#                duration_seconds AS trip_time,
#                RANK() OVER (PARTITION BY start_terminal ORDER BY duration_seconds DESC) AS rank
#           FROM tutorial.dc_bikeshare_q1_2012
#          WHERE start_time < '2012-01-08'
#                ) sub
#  WHERE sub.rank <= 5
# ```

# %% [markdown]
# ![img.png](attachment:img.png)

# %% [markdown]
# ### NTILE

# %% [markdown]
# You can use window functions to identify what percentile (or quartile, or any other subdivision) a given row falls into. The syntax is `NTILE(*# of buckets*)`. In this case, `ORDER BY` determines which column to use to determine the quartiles (or whatever number of 'tiles you specify). For example:

# %% [markdown]
# ```sql
# SELECT start_terminal,
#        duration_seconds,
#        NTILE(4) OVER
#          (PARTITION BY start_terminal ORDER BY duration_seconds)
#           AS quartile
# FROM tutorial.dc_bikeshare_q1_2012
# WHERE start_time < '2012-01-08'
# ORDER BY start_terminal, duration_seconds
# ```

# %% [markdown]
# ![img.png](attachment:img.png)

# %% [markdown]
# **Practice Problem**
#
# Write a query that shows only the duration of the trip and the percentile into which that duration falls (across the entire dataset—not partitioned by terminal).

# %% [markdown]
# ```sql
# SELECT duration_seconds,
#        NTILE(100) OVER (ORDER BY duration_seconds)
#          AS percentile
#   FROM tutorial.dc_bikeshare_q1_2012
#  WHERE start_time < '2012-01-08'
#  ORDER BY 1 DESC
# ```

# %% [markdown]
# ![img.png](attachment:img.png)

# %% [markdown]
# ### LAG and LEAD

# %% [markdown]
# Use `LAG` or `LEAD` to create columns that pull values from other rows - enter which column to pull from and how many rows away you'd like to do the pull. `LAG` pulls from previous rows and `LEAD` pulls from following rows:

# %% [markdown]
# ```sql
# SELECT start_terminal,
#        duration_seconds,
#        LAG(duration_seconds, 1) OVER
#          (PARTITION BY start_terminal ORDER BY duration_seconds) AS lag,
#        LEAD(duration_seconds, 1) OVER
#          (PARTITION BY start_terminal ORDER BY duration_seconds) AS lead
#   FROM tutorial.dc_bikeshare_q1_2012
#  WHERE start_time < '2012-01-08'
#  ORDER BY start_terminal, duration_seconds
# ```

# %% [markdown]
# ![img.png](attachment:img.png)

# %% [markdown]
# This is especially useful if you want to calculate differences between rows:

# %% [markdown]
# ```sql
# SELECT start_terminal,
#        duration_seconds,
#        duration_seconds -LAG(duration_seconds, 1) OVER
#          (PARTITION BY start_terminal ORDER BY duration_seconds)
#          AS difference
#   FROM tutorial.dc_bikeshare_q1_2012
#  WHERE start_time < '2012-01-08'
#  ORDER BY start_terminal, duration_seconds
# ```

# %% [markdown]
# ![img.png](attachment:img.png)

# %% [markdown]
# The first row of the `difference` column is null because there is no previous row from which to pull. Similarly, using `LEAD` will create nulls at the end of the dataset. If you'd like to make the results a bit cleaner, you can wrap it in an outer query to remove nulls:

# %% [markdown]
# ```sql
# SELECT *
#   FROM (
#     SELECT start_terminal,
#            duration_seconds,
#            duration_seconds -LAG(duration_seconds, 1) OVER
#              (PARTITION BY start_terminal ORDER BY duration_seconds)
#              AS difference
#       FROM tutorial.dc_bikeshare_q1_2012
#      WHERE start_time < '2012-01-08'
#      ORDER BY start_terminal, duration_seconds
#        ) sub
#  WHERE sub.difference IS NOT NULL
# ```

# %% [markdown]
# ![img.png](attachment:img.png)

# %% [markdown]
# ### Defining a window alias

# %% [markdown]
# To write several window functions in to the same query, using the same window, you can create an alias:

# %% [markdown]
# ```sql
# SELECT start_terminal,
#        duration_seconds,
#        NTILE(4) OVER
#          (PARTITION BY start_terminal ORDER BY duration_seconds)
#          AS quartile,
#        NTILE(5) OVER
#          (PARTITION BY start_terminal ORDER BY duration_seconds)
#          AS quintile,
#        NTILE(100) OVER
#          (PARTITION BY start_terminal ORDER BY duration_seconds)
#          AS percentile
#   FROM tutorial.dc_bikeshare_q1_2012
#  WHERE start_time < '2012-01-08'
#  ORDER BY start_terminal, duration_seconds
# ```

# %% [markdown]
# **This can be rewritten as:**

# %% [markdown]
# ```sql
# ELECT start_terminal,
#        duration_seconds,
#        NTILE(4) OVER ntile_window AS quartile,
#        NTILE(5) OVER ntile_window AS quintile,
#        NTILE(100) OVER ntile_window AS percentile
#   FROM tutorial.dc_bikeshare_q1_2012
#  WHERE start_time < '2012-01-08'
# WINDOW ntile_window AS
#          (PARTITION BY start_terminal ORDER BY duration_seconds)
#  ORDER BY start_terminal, duration_seconds
# ```

# %% [markdown]
# The `WINDOW` clause, if included, should always come after the `WHERE` clause.

# %% [markdown]
# ## Performance Tuning SQL Queries

# %% [markdown]
# ### The theory behind query run time

# %% [markdown]
# Query runtime is affected by:
# * Table size
# * Joins
# * Aggregations

# %% [markdown]
# Query runtime is also dependent on some things that you can't really control related to the database itself:
# * Other users running queries concurrently on a database
# * Database software and optimization

# %% [markdown]
# ### Reducing table size

# %% [markdown]
# Filtering the data to include only the observations you need can dramatically improve query speed, for example, limiting to a small time window:

# %% [markdown]
# ```sql
# SELECT *
#   FROM benn.sample_event_table
#  WHERE event_date >= '2014-03-01'
#    AND event_date <  '2014-04-01'
# ```

# %% [markdown]
# You can always perform exploratory analysis on a subset of data, refine your work into a final query, then remove the limitation and run your work across the entire dataset.

# %% [markdown]
# ### Making JOINs less complicated

# %% [markdown]
# The following example joins information about college sports teams onto a list of players at various colleges:

# %% [markdown]
# ```sql
# SELECT teams.conference AS conference,
#        players.school_name,
#        COUNT(1) AS players
#   FROM benn.college_football_players players
#   JOIN benn.college_football_teams teams
#     ON teams.school_name = players.school_name
#  GROUP BY 1,2
# ```

# %% [markdown]
# ![img.png](attachment:img.png)

# %% [markdown]
# If the `benn.college_football_players` table was pre-aggregated, you could reduce the number of rows that need to be evaluated in the join.

# %% [markdown]
# ```sql
# SELECT players.school_name,
#        COUNT(*) AS players
#   FROM benn.college_football_players players
#  GROUP BY 1
# ```

# %% [markdown]
# ![img.png](attachment:img.png)

# %% [markdown]
# Dropping the above in a subquery and then joining to it in the outer query will reduce the cost of the join substantially:

# %% [markdown]
# ```sql
# SELECT teams.conference,
#        sub.*
#   FROM (
#         SELECT players.school_name,
#                COUNT(*) AS players
#           FROM benn.college_football_players players
#          GROUP BY 1
#        ) sub
#   JOIN benn.college_football_teams teams
#   ON teams.school_name = sub.school_name
# ```

# %% [markdown]
# ![img.png](attachment:img.png)

# %% [markdown]
# In the case of hundred of thousands of rows or more, you'd see a noticeable improvement by aggregating before joining.

# %% [markdown]
# ### Explain

# %% [markdown]
# Add EXPLAIN at the beginning of any (working) query to get a sense of how long it will take. It's not perfectly accurate, but it's a useful tool.

# %% [markdown]
# ```sql
# EXPLAIN
# SELECT *
#   FROM benn.sample_event_table
#  WHERE event_date >= '2014-03-01'
#    AND event_date < '2014-04-01'
#  LIMIT 100
# ```

# %% [markdown]
# ![img.png](attachment:img.png)

# %% [markdown]
# The above `Query Plan` shows the order in which the query will be executed.
#
# The entry at the bottom of the list is executed first. So this shows that the `WHERE` clause, which limits the date range, will be executed first. Then, the database will scan 600 rows (this is an approximate number). You can see the cost listed next to the number of rows—higher numbers mean longer run time.
#
# You should use this more as a reference than as an absolute measure. To clarify, this is most useful if you run `EXPLAIN` on a query, modify the steps that are expensive, then run `EXPLAIN` again to see if the cost is reduced. Finally, the `LIMIT` clause is executed last.

# %% [markdown]
# ## Pivoting Data in SQL

# %% [markdown]
# ### Pivoting rows to columns

# %% [markdown]
# In this example, we take data that is formatted for analysis and pivot it for presentation or charting

# %% [markdown]
# ```sql
# SELECT teams.conference AS conference,
#        players.year,
#        COUNT(1) AS players
#   FROM benn.college_football_players players
#   JOIN benn.college_football_teams teams
#     ON teams.school_name = players.school_name
#  GROUP BY 1,2
#  ORDER BY 1,2
# ```

# %% [markdown]
# ![img.png](attachment:img.png)

# %% [markdown]
# In order to transform the data, we'll need to put the above query into a subquery. Note that you can eliminate the `ORDER BY` clause from the subquery since we'll reorder the results in the outer query.

# %% [markdown]
# ```sql
# SELECT conference,
#        SUM(players) AS total_players,
#        SUM(CASE WHEN year = 'FR' THEN players ELSE NULL END) AS fr,
#        SUM(CASE WHEN year = 'SO' THEN players ELSE NULL END) AS so,
#        SUM(CASE WHEN year = 'JR' THEN players ELSE NULL END) AS jr,
#        SUM(CASE WHEN year = 'SR' THEN players ELSE NULL END) AS sr
#   FROM (
#         SELECT teams.conference AS conference,
#                players.year,
#                COUNT(1) AS players
#           FROM benn.college_football_players players
#           JOIN benn.college_football_teams teams
#             ON teams.school_name = players.school_name
#          GROUP BY 1,2
#        ) sub
#  GROUP BY 1
#  ORDER BY 2 DESC
# ```

# %% [markdown]
# ![img-2.png](attachment:img-2.png)

# %% [markdown]
# ### Pivoting columns to rows

# %% [markdown]
# ```sql
# SELECT *
#   FROM tutorial.worldwide_earthquakes
# ```

# %% [markdown]
# ![img.png](attachment:img.png)

# %% [markdown]
# In the above format it's challenging to answer questions like "what's the average magnitude of an earthquake?" It would be much easier if the data were displayed in 3 columns: "magnitude", "year", and "number of earthquakes."

# %% [markdown]
# First create a table that lists all of the columns from the original table as rows in a new table:

# %% [markdown]
# ```sql
# SELECT year
#   FROM (VALUES (2000),(2001),(2002),(2003),(2004),(2005)) v(year)
# ```

# %% [markdown]
# ![img.png](attachment:img.png)

# %% [markdown]
# Next, cross join the new table with the `worldwide_earthquakes` table to create an expanded view:

# %% [markdown]
# ```sql
# SELECT years.*,
#        earthquakes.*
#   FROM tutorial.worldwide_earthquakes earthquakes
#  CROSS JOIN (
#        SELECT year
#          FROM (VALUES (2000),(2001),(2002),(2003),(2004),(2005)) v(year)
#        ) years
# ```

# %% [markdown]
# ![img.png](attachment:img.png)

# %% [markdown]
# Each row in the `worldwide_earthquakes` is replicated 6 times. In the final step we fix this using a `CASE` statement that pulls data from the correct column in the `worldwide_earthquakes` table given the value in the `year` column:

# %% [markdown]
# ```sql
# SELECT years.*,
#        earthquakes.magnitude,
#        CASE year
#          WHEN 2000 THEN year_2000
#          WHEN 2001 THEN year_2001
#          WHEN 2002 THEN year_2002
#          WHEN 2003 THEN year_2003
#          WHEN 2004 THEN year_2004
#          WHEN 2005 THEN year_2005
#          ELSE NULL END
#          AS number_of_earthquakes
#   FROM tutorial.worldwide_earthquakes earthquakes
#  CROSS JOIN (
#        SELECT year
#          FROM (VALUES (2000),(2001),(2002),(2003),(2004),(2005)) v(year)
#        ) years
# ```

# %% [markdown]
# ![img.png](attachment:img.png)
